# %%
import requests

url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/stock/v2/get-financials"

querystring = {"symbol":"TSLA","region":"US"}

headers = {
    'x-rapidapi-key': "44b61fa44fmshb99af41ee0b18d6p124b40jsn67aa83cc9b01",
    'x-rapidapi-host': "apidojo-yahoo-finance-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

data = response.json()

# %%
url_1 = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/stock/get-histories"

querystring_1 = {"symbol":"TSLA","from":"1546448400","to":"1562086800","events":"div","interval":"1d","region":"US"}

headers_1 = {
    'x-rapidapi-key': "44b61fa44fmshb99af41ee0b18d6p124b40jsn67aa83cc9b01",
    'x-rapidapi-host': "apidojo-yahoo-finance-v1.p.rapidapi.com"
    }

response_1 = requests.request("GET", url, headers=headers, params=querystring)

data_analysis = response_1.json()

# %%
#Pull 4th quarter financial data current year

q4y1_gross_profit = data['incomeStatementHistoryQuarterly']['incomeStatementHistory'][0]['grossProfit']['longFmt']
q4y1_total_revenue = data['incomeStatementHistoryQuarterly']['incomeStatementHistory'][0]['totalRevenue']['longFmt']
q4y1_earnings_estimate = data['earnings']['earningsChart']['currentQuarterEstimate']['fmt']

#Pull 3rd Quarter financial data current year

q3y1_gross_profit = data['incomeStatementHistoryQuarterly']['incomeStatementHistory'][1]['grossProfit']['longFmt']
q3y1_total_revenue = data['incomeStatementHistoryQuarterly']['incomeStatementHistory'][1]['totalRevenue']['longFmt']
q3y1_earnings = data['earnings']['financialsChart']['quarterly'][3]['earnings']['longFmt']

#Pull 2nd Quarter financial data current year
q2y1gross_profit = data['incomeStatementHistoryQuarterly']['incomeStatementHistory'][2]['grossProfit']['longFmt']
q2y1_total_revenue = data['incomeStatementHistoryQuarterly']['incomeStatementHistory'][2]['totalRevenue']['longFmt']
q2y1_earnings = data['earnings']['financialsChart']['quarterly'][2]['earnings']['longFmt']

#Pull 1st Quarter financial data current year
q1y1gross_profit = data['incomeStatementHistoryQuarterly']['incomeStatementHistory'][3]['grossProfit']['longFmt']
q1y1_total_revenue = data['incomeStatementHistoryQuarterly']['incomeStatementHistory'][3]['totalRevenue']['longFmt']
q1y1_earnings = data['earnings']['financialsChart']['quarterly'][1]['earnings']['longFmt']

#Pull 4th Quarter fincancial data last year
q4y2_earnings = data['earnings']['financialsChart']['quarterly'][0]['earnings']['longFmt']
#Pull 3rd Quarter fincancial data last year

#Pull 2nd Quarter fincancial data last year

#Pull 1st Quarter fincancial data last year

# %%
q4y2_earnings
# Out:
# '105,000,000'

# %%
import requests

url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/stock/v3/get-historical-data"

querystring = {"symbol":"AMRN","region":"US"}

headers = {
    'x-rapidapi-key': "44b61fa44fmshb99af41ee0b18d6p124b40jsn67aa83cc9b01",
    'x-rapidapi-host': "apidojo-yahoo-finance-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"prices":[{"date":1611694801,"open":7.740200042724609,"high":7.800000190734863,"low":7.309999942779541,"close":7.480000019073486,"volume":9916575,"adjclose":7.480000019073486},{"date":1611585000,"open":7.170000076293945,"high":7.639999866485596,"low":6.960000038146973,"close":7.559999942779541,"volume":13929800,"adjclose":7.559999942779541},{"date":1611325800,"open":6.590000152587891,"high":6.630000114440918,"low":6.340000152587891,"close":6.550000190734863,"volume":6110300,"adjclose":6.550000190734863},{"date":1611239400,"open":6.170000076293945,"high":6.369999885559082,"low":6.050000190734863,"close":6.309999942779541,"volume":5888600,"adjclose":6.309999942779541},{"date":1611153000,"open":6.389999866485596,"high":6.389999866485596,"low":6.079999923706055,"close":6.199999809265137,"volume":6111900,"adjclose":6.199999809265137},{"date":1611066600,"open":6.190000057220459,"high":6.579999923706055,"low":6.139999866485596,"close":6.289999961853027,"volume":8727700,"adjclose":6.2899999
# ...
