# %%
from datetime import datetime
import requests

# %%
ts = int("1546448400")
ts_1 = int("1562086800")

# if you encounter a "year is out of range" error the timestamp
# may be in milliseconds, try `ts /= 1000` in that case
print(datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S'))
print(datetime.utcfromtimestamp(ts_1).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2019-01-02 17:00:00
# 2019-07-02 17:00:00

# %%
from alpha_vantage.timeseries import TimeSeries

# %%
def 

base_url = 'https://www.alphavantage.co/query?'
params = {'function': 'EARNINGS',
         'symbol': 'IBM',
         'apikey': 'UU7Q8Q1FOSXOGG14'}

response = requests.get(base_url, params=params)
data = response.json()

# %%
def pull_alpha_data(function, ticker): 

    base_url = 'https://www.alphavantage.co/query?'
    params = {'function': function,
             'symbol': ticker,
             'apikey': 'UU7Q8Q1FOSXOGG14'}

    response = requests.get(base_url, params=params)
    data = response.json()
    return data

data = pull_alpha_data('OVERVIEW', 'TSLA')

# %%
#Quarterly Earnings Growth YOY - Alphavantage
earnings_growth = data['QuarterlyEarningsGrowthYOY']
#Quarterly Revenue Growth YOY- Alphavantage 
revenue_growth = data['QuarterlyRevenueGrowthYOY']
#Profit Margin - Alphavantage
profit_margin = data['ProfitMargin']
#52 Week High - Alphavantage
fifty_two_wk_high = data['52WeekHigh']

#52 Week Low - Alphavantage
fity_two_wk_low = data['52WeekLow']
#Beta - Alphavantage
beta = data['Beta']
#EPS - Alphavantage
eps = data['EPS']

# %%
data
# Out:
# {'Symbol': 'TSLA',
#  'AssetType': 'Common Stock',
#  'Name': 'Tesla, Inc',
# ...

# %%
pull_alpha_data('CASH_FLOW', 'IBM')
# Out:
# {'symbol': 'IBM',
#  'annualReports': [{'fiscalDateEnding': '2020-12-31',
#    'reportedCurrency': 'USD',
#    'investments': '-3028000000',
#    'changeInLiabilities': '0',
#    'cashflowFromInvestment': '-3028000000',
#    'otherCashflowFromInvestment': 'None',
#    'netBorrowings': '-3714000000',
#    'cashflowFromFinancing': '-9721000000',
#    'otherCashflowFromFinancing': 'None',
#    'changeInOperatingActivities': '4974000000',
#    'netIncome': '5590000000',
#    'changeInCash': '5361000000',
#    'operatingCashflow': '18197000000',
#    'otherOperatingCashflow': 'None',
#    'depreciation': '6695000000',
#    'dividendPayout': '-5797000000',
#    'stockSaleAndPurchase': '-210000000',
#    'changeInInventory': 'None',
#    'changeInAccountReceivables': '4349000000',
#    'changeInNetIncome': '938000000',
#    'capitalExpenditures': '3042000000',
#    'changeInReceivables': 'None',
#    'changeInExchangeRate': 'None',
#    'changeInCashAndCashEquivalents': 'None'},
# ...
